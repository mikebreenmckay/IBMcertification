# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Michael Breen-McKay**
# Data Scientist

# %% [markdown]
# *I am interested in data science because it gives us insights into the world around us and can be used to help solve systemic problems. I hope to be able to use data to tell stories about the information and find actionable solutions to business AND societal issues.*

# %% [markdown]
# ### The code in cell 5 will print the first five squares.

# %%
for i in range(5):
    print((i+1)**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Final Cell
#
# ------
#
# - Not the first cell
# - Not the second cell
# - Not the Penultimate cell
#
# > So much markdown!
